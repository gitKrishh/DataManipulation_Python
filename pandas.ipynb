# %%
import pandas as pd

# %%
## To read a csv file
df = pd.read_csv('data.csv')

# %%
df1 = df.head(5)
df1
# Out:
#    Index      Customer Id First Name Last Name  \
# 0    1.0  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1    2.0  1Ef7b82A4CAAD10    Preston    Lozano
# 2    NaN  6F94879bDAfE5a6        Roy     Berry
# 3    4.0  5Cef8BFA16c5e3c      Linda     Olsen
# 4    5.0  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry              NULL
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
#checking missing value
df1.isnull()
# Out:
#    Index  Customer Id  First Name  Last Name  Company   City  Country  \
# 0  False        False       False      False    False  False    False
# 1  False        False       False      False    False  False    False
# 2   True        False       False      False    False  False    False
# 3  False        False       False      False    False  False    False
# 4  False        False       False      False    False  False    False
#
#    Phone 1  Phone 2  Email   Date  Website
# 0    False    False  False   True    False
# 1    False    False  False  False    False
# 2    False    False  False  False    False
# 3    False    False  False  False    False
# 4    False    False  False  False    False

# %%
##filling the missing values with the mean of the column
df['Date_fillNA'] = df1['Date'].fillna(df1['Date'].mean())
df.head(5) ## filhal it is in date time format that is why it is giiving a error

# %%
df.dtypes
# Out:
# Index           int64
# Customer Id    object
# First Name     object
# Last Name      object
# Company        object
# City           object
# Country        object
# Phone 1        object
# Phone 2        object
# Email          object
# Date           object
# Website        object
# dtype: object

# %%
##Renaming columns:
df2 = df1.rename(columns={'Date': 'Dates'})
df2
# Out:
#    Index      Customer Id First Name Last Name  \
# 0    1.0  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1    2.0  1Ef7b82A4CAAD10    Preston    Lozano
# 2    NaN  6F94879bDAfE5a6        Roy     Berry
# 3    4.0  5Cef8BFA16c5e3c      Linda     Olsen
# 4    5.0  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry              NULL
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
## change datatypes:
df['Index_new'] = df['Index'].fillna(3.0).astype(float)
df.head(5)
# Out:
#    Index      Customer Id First Name Last Name  \
# 0    1.0  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1    2.0  1Ef7b82A4CAAD10    Preston    Lozano
# 2    NaN  6F94879bDAfE5a6        Roy     Berry
# 3    4.0  5Cef8BFA16c5e3c      Linda     Olsen
# 4    5.0  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry              NULL
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
df2 = pd.read_csv('products-100.csv')
df2.head(5)
# Out:
#    Index                                  Name  \
# 0      1  Compact Printer Air Advanced Digital
# 1      2                                Tablet
# 2      3                  Smart Blender Cooker
# 3      4          Advanced Router Rechargeable
# 4      5          Portable Mouse Monitor Phone
#
#                                          Description  \
# 0      Situation organization these memory much off.
# 1        Discussion loss politics free one thousand.
# 2                                  No situation per.
# 3                    For force gas energy six laugh.
# 4  Feeling back religious however author room sci...
#
#                         Brand            Category  Price Currency  Stock  \
# 0     Garner, Boyle and Flynn  Books & Stationery  265.0      USD    774
# 1                 Mueller Inc    Shoes & Footwear  502.0      USD     81
# 2  Lawson, Keller and Winters  Kitchen Appliances    NaN      USD    726
# ...

# %%
df2['Price_fillNA'] = df2['Price'].fillna(df2['Price'].mean())
df2.head(5)
# Out:
#    Index                                  Name  \
# 0      1  Compact Printer Air Advanced Digital
# 1      2                                Tablet
# 2      3                  Smart Blender Cooker
# 3      4          Advanced Router Rechargeable
# 4      5          Portable Mouse Monitor Phone
#
#                                          Description  \
# 0      Situation organization these memory much off.
# 1        Discussion loss politics free one thousand.
# 2                                  No situation per.
# 3                    For force gas energy six laugh.
# 4  Feeling back religious however author room sci...
#
#                         Brand            Category  Price Currency  Stock  \
# 0     Garner, Boyle and Flynn  Books & Stationery  265.0      USD    774
# 1                 Mueller Inc    Shoes & Footwear  502.0      USD     81
# 2  Lawson, Keller and Winters  Kitchen Appliances    NaN      USD    726
# ...

# %%
##Data Aggregating And Grouping
df2.head()
# Out:
#    Index                                  Name  \
# 0      1  Compact Printer Air Advanced Digital
# 1      2                                Tablet
# 2      3                  Smart Blender Cooker
# 3      4          Advanced Router Rechargeable
# 4      5          Portable Mouse Monitor Phone
#
#                                          Description  \
# 0      Situation organization these memory much off.
# 1        Discussion loss politics free one thousand.
# 2                                  No situation per.
# 3                    For force gas energy six laugh.
# 4  Feeling back religious however author room sci...
#
#                         Brand            Category  Price Currency  Stock  \
# 0     Garner, Boyle and Flynn  Books & Stationery  265.0      USD    774
# 1                 Mueller Inc    Shoes & Footwear  502.0      USD     81
# 2  Lawson, Keller and Winters  Kitchen Appliances    NaN      USD    726
# ...

# %%
grouped_mean= df2.groupby('---')['Price'].mean() ## by this if there is same things many time in a column then it will group them and lovely it can also sum or do things like taking mean of price

# %%
#ex:
grouped_mean = df2.groupby('Currency')['Price'].mean()
print(grouped_mean)
# Out:
# Currency
# USD    453.454545
# Name: Price, dtype: float64

# %%
#ex2:
grouped_sum = df2.groupby('Currency')['Price'].sum()
print(grouped_sum)
# Out:
# Currency
# USD    44892.0
# Name: Price, dtype: float64

# %%
## Merging and joining dataframes
#Create sample dataframes
df1 = pd.DataFrame({'Key':['A', 'B', 'C'], 'Value1': [1,2,3]})
df2 = pd.DataFrame({'Key':['A', 'B', 'D'], 'Value2': [4,5,6]})

# %%
df1
# Out:
#   Key  Value1
# 0   A       1
# 1   B       2
# 2   C       3

# %%
df2
# Out:
#   Key  Value2
# 0   A       4
# 1   B       5
# 2   D       6

# %%
## Merge the dataframe on the key columns
pd.merge(df1, df2, on='Key', how="inner")
# Out:
#   Key  Value1  Value2
# 0   A       1       4
# 1   B       2       5

# %%
pd.merge(df1, df2, on='Key', how="outer")
# Out:
#   Key  Value1  Value2
# 0   A     1.0     4.0
# 1   B     2.0     5.0
# 2   C     3.0     NaN
# 3   D     NaN     6.0

# %%
pd.merge(df1, df2, on='Key', how="left") ##val1 will be prioritise
# Out:
#   Key  Value1  Value2
# 0   A       1     4.0
# 1   B       2     5.0
# 2   C       3     NaN

# %%
pd.merge(df1, df2, on='Key', how="right") ##right side is prioritise
# Out:
#   Key  Value1  Value2
# 0   A     1.0       4
# 1   B     2.0       5
# 2   D     NaN       6
